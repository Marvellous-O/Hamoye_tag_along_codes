# %%
#Importing needed libraries
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the Dataset
df= pd.read_csv('/content/Africa Food Production (2004 - 2013).csv')

# %%
df
# Out:
#         Country                Item  Year  Value
# 0       Algeria  Wheat and products  2004   2731
# 1       Algeria  Wheat and products  2005   2415
# 2       Algeria  Wheat and products  2006   2688
# 3       Algeria  Wheat and products  2007   2319
# 4       Algeria  Wheat and products  2008   1111
# ...         ...                 ...   ...    ...
# 23105  Zimbabwe         Crustaceans  2009      0
# 23106  Zimbabwe         Crustaceans  2010      0
# 23107  Zimbabwe         Crustaceans  2011      0
# 23108  Zimbabwe         Crustaceans  2012      0
# 23109  Zimbabwe         Crustaceans  2013      0
#
# [23110 rows x 4 columns]

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Country    0
# Item       0
# Year       0
# Value      0
# dtype: int64

# %%
df.shape
# Out:
# (23110, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23110 entries, 0 to 23109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  23110 non-null  object
#  1   Item     23110 non-null  object
#  2   Year     23110 non-null  int64
#  3   Value    23110 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 722.3+ KB

# %%
df.describe()
# Out:
#                Year         Value
# count  23110.000000  23110.000000
# mean    2008.498269    327.785201
# std        2.871740   1607.940343
# min     2004.000000      0.000000
# 25%     2006.000000      3.000000
# 50%     2008.000000     18.000000
# 75%     2011.000000    108.000000
# max     2013.000000  54000.000000

# %%
#Converting the year column to Datetime
#df['Year']= pd.to_datetime(df['Year']).dt.year
df['Year']=pd.to_datetime(df.Year, format='%Y').dt.year

# %%
df.head()
# Out:
#    Country                Item  Year  Value
# 0  Algeria  Wheat and products  2004   2731
# 1  Algeria  Wheat and products  2005   2415
# 2  Algeria  Wheat and products  2006   2688
# 3  Algeria  Wheat and products  2007   2319
# 4  Algeria  Wheat and products  2008   1111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23110 entries, 0 to 23109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  23110 non-null  object
#  1   Item     23110 non-null  object
#  2   Year     23110 non-null  int64
#  3   Value    23110 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 722.3+ KB

# %%
#Adding the kiloton unit to the value column
df['Value_kt']= df['Value'].astype(str)
df['Value_kt']=df['Value_kt']+ 'kt'

# %%
df.head()
# Out:
#    Country                Item  Year  Value Value_kt
# 0  Algeria  Wheat and products  2004   2731   2731kt
# 1  Algeria  Wheat and products  2005   2415   2415kt
# 2  Algeria  Wheat and products  2006   2688   2688kt
# 3  Algeria  Wheat and products  2007   2319   2319kt
# 4  Algeria  Wheat and products  2008   1111   1111kt

# %%
#Grouping the dataset by each column
df.groupby(['Country', 'Year', 'Item'])['Value'].sum() #, 'Year', 'Value'])
# Out:
# Country   Year  Item
# Algeria   2004  Apples and products       165
#                 Bananas                     0
#                 Barley and products      1212
#                 Beans                       2
#                 Beer                      110
#                                          ...
# Zimbabwe  2013  Tea (including mate)       19
#                 Tomatoes and products      24
#                 Vegetables, Other         203
#                 Wheat and products         25
#                 Wine                        2
# Name: Value, Length: 23110, dtype: int64

# %%
df.head()
# Out:
#    Country                Item  Year  Value Value_kt
# 0  Algeria  Wheat and products  2004   2731   2731kt
# 1  Algeria  Wheat and products  2005   2415   2415kt
# 2  Algeria  Wheat and products  2006   2688   2688kt
# 3  Algeria  Wheat and products  2007   2319   2319kt
# 4  Algeria  Wheat and products  2008   1111   1111kt

# %%
#Applying a groupby function to show the sum of vales by year
df.groupby(['Country', 'Year'])['Value'].sum()
# Out:
# Country   Year
# Algeria   2004    15536
#           2005    15667
#           2006    16417
#           2007    14763
#           2008    13841
#                   ...
# Zimbabwe  2009     5754
#           2010     6777
#           2011     7551
#           2012     8173
#           2013     7914
# Name: Value, Length: 450, dtype: int64

# %%
df.head()
# Out:
#    Country                Item  Year  Value Value_kt
# 0  Algeria  Wheat and products  2004   2731   2731kt
# 1  Algeria  Wheat and products  2005   2415   2415kt
# 2  Algeria  Wheat and products  2006   2688   2688kt
# 3  Algeria  Wheat and products  2007   2319   2319kt
# 4  Algeria  Wheat and products  2008   1111   1111kt

# %%
#Checking the columns
df.columns
# Out:
# Index(['Country', 'Item', 'Year', 'Value', 'Value_kt'], dtype='object')

# %%
df.Country.nunique()
# Out:
# 45

# %%
#A line plot
plt.plot(df['Year'],df['Country'])
plt.figure(figsize=(30,15))
plt.show()

# %%
#create a line plot to visualize the countries
#plt.plot(df['Year'],['Country'])
#plt.show()

# %%
#Importing the supply dataset
df_= pd.read_csv('/content/Africa Food Supply (2004 - 2013).csv')
df_.head()
# Out:
#    Country  Year  Value
# 0  Algeria  2004   2987
# 1  Algeria  2005   2958
# 2  Algeria  2006   3047
# 3  Algeria  2007   3041
# 4  Algeria  2008   3048

# %%
#Change the Year column to Datetime
df_['Year']=pd.to_datetime(df_.Year, format='%Y').dt.year
df_.head()
# Out:
#    Country  Year  Value
# 0  Algeria  2004   2987
# 1  Algeria  2005   2958
# 2  Algeria  2006   3047
# 3  Algeria  2007   3041
# 4  Algeria  2008   3048

# %%
#To check the data types
df_.info
# Out:
# <bound method DataFrame.info of       Country  Year  Value
# 0     Algeria  2004   2987
# 1     Algeria  2005   2958
# 2     Algeria  2006   3047
# 3     Algeria  2007   3041
# 4     Algeria  2008   3048
# ..        ...   ...    ...
# 445  Zimbabwe  2009   2147
# 446  Zimbabwe  2010   2168
# 447  Zimbabwe  2011   2200
# 448  Zimbabwe  2012   2197
# 449  Zimbabwe  2013   2110
#
# [450 rows x 3 columns]>

# %%
#adding the unit to the value column
df_['Value_2']= df_['Value'].astype(str)
df_['Value_2']=df_['Value_2']+ 'kcal/person/day'
df_.head()
# Out:
#    Country  Year  Value              Value_2
# 0  Algeria  2004   2987  2987kcal/person/day
# 1  Algeria  2005   2958  2958kcal/person/day
# 2  Algeria  2006   3047  3047kcal/person/day
# 3  Algeria  2007   3041  3041kcal/person/day
# 4  Algeria  2008   3048  3048kcal/person/day

# %%
#Grouping by Year to show sum of values
df1=df_.groupby('Year')['Value'].sum().reset_index()
df1.head
# Out:
# <bound method NDFrame.head of    Year   Value
# 0  2004  107740
# 1  2005  108418
# 2  2006  109386
# 3  2007  110149
# 4  2008  110734
# 5  2009  111700
# 6  2010  112383
# 7  2011  113194
# 8  2012  113744
# 9  2013  113951>

# %%
df1=df_.groupby(['Country', 'Year'])['Value'].sum().reset_index()
df1.head
# Out:
# <bound method NDFrame.head of       Country  Year  Value
# 0     Algeria  2004   2987
# 1     Algeria  2005   2958
# 2     Algeria  2006   3047
# 3     Algeria  2007   3041
# 4     Algeria  2008   3048
# ..        ...   ...    ...
# 445  Zimbabwe  2009   2147
# 446  Zimbabwe  2010   2168
# 447  Zimbabwe  2011   2200
# 448  Zimbabwe  2012   2197
# 449  Zimbabwe  2013   2110
#
# [450 rows x 3 columns]>

# %%
#sns.boxplot(data=df_, x="Country", y="Value")
df_2012 = df_[df_['Year'] == 2012]
sns.boxplot(data =df_2012, x='Country' ,y='Value')
# Out:
# <Axes: xlabel='Country', ylabel='Value'>

# %%
#Plotting a boxplot to show the values by each year revealing the outliers
sns.boxplot(data=df_, x="Year", y="Value")
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
#Boxplot of Values for Each Year for the Production dataset
plt.figure(figsize=(8, 4))
plt.boxplot([df[df['Year'] == year]['Value'] for year in df['Year'].unique()],
            labels=df['Year'].unique())

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Boxplot of Values for Each Year')

# Show the plot
plt.show()

# %%
#Boxplot of Values for Each Year for the Supply dataset
plt.figure(figsize=(8, 4))
plt.boxplot([df_[df_['Year'] == year]['Value'] for year in df_['Year'].unique()],
            labels=df_['Year'].unique())

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Boxplot of Values for Each Year')

# Show the plot
plt.show()

# %%
#box plot showing for year 2004 only with multiple outliers
selected_year = 2004

# Filter the data for the selected year
selected_year_data = df_[df_['Year'] == selected_year]

# Create a boxplot for the selected year
plt.figure(figsize=(6, 4))
plt.boxplot(selected_year_data['Value'], labels=[selected_year])

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Value')
plt.title(f'Boxplot of Values for 2004')

# Show the plot
plt.show()

# %%
# boxplot showing the values grouped by countries
plt.figure(figsize=(10, 6))
boxplot = df_.boxplot(by='Country', column='Value', grid=False)

# Add labels and title
plt.xlabel('Country')
plt.ylabel('Value')
plt.title('Boxplot of Values by Country')
plt.show()
